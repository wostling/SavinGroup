# %%
import pandas as pd
def combine files(file_list, column_list):
    return_dataframe = pd.DataFrame()
    i=0
    for file in file_list:
        data = pd.read_fwf(file)
        i+=1
# Out:
#   Cell In[2], line 2
#     def combine files(file_list, column_list):
#                 ^
# SyntaxError: invalid syntax

# %%
data = pd.read_csv("C:/Users/willi/Desktop/Savin Group/column select from multiple files/24_07_15_11_49_13.dat", sep='\t')

# %%
data
# Out:
#       -6.000E+0  5.103E-3  -6.000E+0.1  3.929E-1  -6.000E+0.2  1.196E-2  \
# 0         -5.99 -0.001501        -5.99    0.3924        -5.99 -0.001944
# 1         -5.98  0.001073        -5.98    0.3748        -5.98  0.002642
# 2         -5.97 -0.000889        -5.97    0.3435        -5.97  0.006216
# 3         -5.96  0.005586        -5.96    0.3112        -5.96 -0.000135
# 4         -5.95  0.008652        -5.95    0.2862        -5.95  0.002384
# ...         ...       ...          ...       ...          ...       ...
# 1195       5.95  0.000551         5.95    0.2751         5.95 -0.002732
# 1196       5.96  0.003782         5.96    0.3072         5.96 -0.006641
# 1197       5.97 -0.005862         5.97    0.3227         5.97  0.003590
# 1198       5.98  0.003993         5.98    0.3596         5.98 -0.007506
# 1199       5.99  0.004004         5.99    0.3824         5.99 -0.004883
#
#       -6.000E+0.3  4.565E-1
# 0           -5.99    0.4460
# 1           -5.98    0.4181
# ...
