# %%
import io
import numpy as np
from scipy import optimize
import pandas as pd
import matplotlib.pyplot as plt
import math
#%matplotlib qt
# %matplotlib inline

# %%
CH2_energies = [7.62E-03, 4.83E-02, 1.69E-01, 3.68E-01, 7.57E-01, 1.28E+00, 1.95E+00, 3.19E+00]
CH2_rates = [4.24E-11,
3.50E-11,
2.90E-11,
2.39E-11,
1.81E-11,
1.34E-11,
1.13E-11,
2.44E-12,

]

# %%
plt.plot(CH2_energies, CH2_rates)
plt.xscale("log")
